# %% [markdown]
# <a href="https://colab.research.google.com/github/Whatthe-we/AIFFEL_quest_cr/blob/master/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 4-1
from tensorflow.keras.datasets import imdb

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

# %%
# 4-2
word_index = imdb.get_word_index()
reverse_word_index = dict(
    [(value, key) for (key, value) in word_index.items()])
decoded_review = " ".join(
    [reverse_word_index.get(i - 3, "?") for i in train_data[0]])

# %%
'''
# IMDb 데이터셋에서 단어 인덱스를 가져옵니다.
# 결과는 {단어: 인덱스} 형태의 딕셔너리로 반환됩니다.
word_index = imdb.get_word_index()

# 단어 인덱스를 반대로 변환하여 {인덱스: 단어} 형태의 딕셔너리를 만듭니다.
# 이를 통해 숫자로 표현된 인덱스를 다시 단어로 변환할 수 있습니다.
reverse_word_index = dict(
    [(value, key) for (key, value) in word_index.items()]
)

# 첫 번째 리뷰를 디코딩(숫자를 단어로 변환)합니다.
# train_data[0]는 숫자로 표현된 첫 번째 리뷰입니다.
# 각 숫자 i에서 3을 뺀 값을 reverse_word_index에서 찾아 단어로 변환합니다.
# 특별한 경우(인덱스가 없을 경우)에는 "?"를 기본값으로 사용합니다.
decoded_review = " ".join(
    [reverse_word_index.get(i - 3, "?") for i in train_data[0]]
)

# %%
# 4-3
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        for j in sequence:
            results[i, j] = 1.
    return results

x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
'''
# 주어진 시퀀스를 벡터로 변환하는 함수
def vectorize_sequences(sequences, dimension=10000):
    # 시퀀스의 길이만큼, dimension 크기의 제로 배열을 생성
    results = np.zeros((len(sequences), dimension))

    # 각 시퀀스를 반복
    for i, sequence in enumerate(sequences):
        # 각 시퀀스에서의 각 단어 인덱스를 순회
        for j in sequence:
            # 해당 인덱스 위치를 1로 설정 (원-핫 인코딩 방식)
            results[i, j] = 1.
            j는 각 시퀀스에서 단어를 인덱스 번호로 표현한 값

    # 변환된 결과 반환
    return results

# 훈련 데이터와 테스트 데이터를 벡터로 변환
x_train = vectorize_sequences(train_data)  # 훈련 데이터를 벡터화
x_test = vectorize_sequences(test_data)    # 테스트 데이터를 벡터화
'''
# Out:
# '\n# 주어진 시퀀스를 벡터로 변환하는 함수\ndef vectorize_sequences(sequences, dimension=10000):\n    # 시퀀스의 길이만큼, dimension 크기의 제로 배열을 생성\n    results = np.zeros((len(sequences), dimension)) \n    \n    # 각 시퀀스를 반복\n    for i, sequence in enumerate(sequences):\n        # 각 시퀀스에서의 각 단어 인덱스를 순회\n        for j in sequence:\n            # 해당 인덱스 위치를 1로 설정 (원-핫 인코딩 방식)\n            results[i, j] = 1.\n    \n    # 변환된 결과 반환\n    return results\n\n# 훈련 데이터와 테스트 데이터를 벡터로 변환\nx_train = vectorize_sequences(train_data)  # 훈련 데이터를 벡터화\nx_test = vectorize_sequences(test_data)    # 테스트 데이터를 벡터화\n'

# %%
# 4-4
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# %%
# 4-5 모델 컴파일하기
model.compile(optimizer="rmsprop",
             loss="binary_crossentropy", # 손실함수 binary_crossentropy 사용
             metrics=["accuracy"])

# %%
# 4-6
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = train_labels[:10000]  # y_train -> train_labels로 수정
partial_y_train = train_labels[10000:]

# %%
# 4-7
history = model.fit(
    partial_x_train,  # 훈련 데이터 (훈련 데이터의 일부)
    partial_y_train,  # 훈련 데이터의 레이블 (훈련 데이터의 일부에 해당하는 레이블)
    epochs=20,  # 모델 훈련을 20번 반복 (에포크 수)
    batch_size=512,  # 한 번의 훈련에서 처리할 데이터 샘플 수 (배치 크기)
    validation_data=(x_val, y_val)  # 검증 데이터 (훈련 중간에 모델을 검증하기 위해 사용)
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.7044 - loss: 0.6077 - val_accuracy: 0.8613 - val_loss: 0.4134
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8898 - loss: 0.3603 - val_accuracy: 0.8824 - val_loss: 0.3262
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9165 - loss: 0.2654 - val_accuracy: 0.8882 - val_loss: 0.2916
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.9350 - loss: 0.2089 - val_accuracy: 0.8901 - val_loss: 0.2764
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9441 - loss: 0.1769 - val_accuracy: 0.8899 - val_loss: 0.2757
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9540 - loss: 0.1451 - val_accuracy: 0.8855 - val_loss: 0.2830
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9610 - loss: 0.1279 - val_accuracy: 0.8851 - val_loss: 0.3001
# Epoch 8/20
# ...

# %%
# 4-8
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss") # bo는 파란색 점

plt.plot(epochs, val_loss_values, "b", label="Validation loss") # b는 파란색 실선
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# 4-9
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label = "Training acc")
plt.plot(epochs, val_acc, "b", label = "Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
# 4-10
model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-f4c30f15f057> in <cell line: 10>()
#       8               loss="binary_crossentropy",
#       9               metrics=["accuracy"])
# ---> 10 model.fit(x_train, y_train, epochs=4, batch_size=512)
#      11 results = model.evaluate(x_test, y_test)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     106       dtype = dtypes.as_dtype(dtype).as_datatype_enum
# ...

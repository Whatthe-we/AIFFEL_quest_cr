# %% [markdown]
# <a href="https://colab.research.google.com/github/Whatthe-we/AIFFEL_quest_cr/blob/master/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 5-1
from tensorflow.keras.datasets import mnist
import numpy as np

(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
train_images_with_noise_channels = np.concatenate(
    [train_images, np.random.random((len(train_images), 784))], axis=1)
train_images_with_zeros_channels = np.concatenate(
    [train_images, np.zeros((len(train_images), 784))], axis=1)

# %%
# 5-2
from tensorflow import keras
from tensorflow.keras import layers

def get_model():
    model = keras.Sequential([
      layers.Dense(512, activation="relu"),
      layers.Dense(10, activation="softmax")
    ])
    model.compile(optimizer="rmsprop",
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    return model

model = get_model()
history_noise = model.fit(
    train_images_with_noise_channels, train_labels,
    epochs=10,
    batch_size=128,
    validation_split=0.2)

model = get_model()
history_zero = model.fit(
    train_images_with_zeros_channels, train_labels,
    epochs=10,
    batch_size=128,
    validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.6948 - loss: 1.0676 - val_accuracy: 0.9133 - val_loss: 0.2745
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.9149 - loss: 0.2742 - val_accuracy: 0.9454 - val_loss: 0.1778
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.9449 - loss: 0.1697 - val_accuracy: 0.9422 - val_loss: 0.1882
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9626 - loss: 0.1219 - val_accuracy: 0.9557 - val_loss: 0.1530
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9722 - loss: 0.0894 - val_accuracy: 0.9656 - val_loss: 0.1168
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.9798 - loss: 0.0628 - val_accuracy: 0.9492 - val_loss: 0.1733
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9859 - loss: 0.0454 - val_accuracy: 0.9622 - val_loss: 0.1360
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.9891 - loss: 0.0356 - val_accuracy: 0.9651 - val_loss: 0.1317
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.9916 - loss: 0.0277 - val_accuracy: 0.9632 - val_loss: 0.1436
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9951 - loss: 0.0172 - val_accuracy: 0.9636 - val_loss: 0.1470
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.8592 - loss: 0.4872 - val_accuracy: 0.9567 - val_loss: 0.1479
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9619 - loss: 0.1332 - val_accuracy: 0.9672 - val_loss: 0.1094
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9760 - loss: 0.0850 - val_accuracy: 0.9752 - val_loss: 0.0860
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9833 - loss: 0.0573 - val_accuracy: 0.9748 - val_loss: 0.0860
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9875 - loss: 0.0437 - val_accuracy: 0.9777 - val_loss: 0.0793
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.9911 - loss: 0.0310 - val_accuracy: 0.9785 - val_loss: 0.0740
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9939 - loss: 0.0221 - val_accuracy: 0.9769 - val_loss: 0.0857
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9954 - loss: 0.0177 - val_accuracy: 0.9783 - val_loss: 0.0799
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9970 - loss: 0.0137 - val_accuracy: 0.9778 - val_loss: 0.0785
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.9979 - loss: 0.0102 - val_accuracy: 0.9805 - val_loss: 0.0744

# %%
# 5-3
import matplotlib.pyplot as plt

val_acc_noise = history_noise.history["val_accuracy"]
val_acc_zeros = history_zero.history["val_accuracy"]
epochs = range(1, 11)
plt.plot(epochs, val_acc_noise, "b-",
         label="Validation accuracy with noise channels")
plt.plot(epochs, val_acc_zeros, "b--",
         label="Validation accuracy with zeros channels")
plt.title("Effect of noise channels on validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
# 5-4
(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
# mnist가 0~255 사이의 정수로 표현됨. 이를 작은 범위로 정규화하기 위해서 255로 나눔
# ex) 픽셀 값이 128/255 : 0.502 (0~1 범위로 변환)

random_train_labels = train_labels[:]
np.random.shuffle(random_train_labels)

model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
model.fit(train_images, random_train_labels,
          epochs=100,
          batch_size=128,
          validation_split=0.2)
# Out:
# Epoch 1/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.1064 - loss: 2.3297 - val_accuracy: 0.1064 - val_loss: 2.3047
# Epoch 2/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.1195 - loss: 2.2977 - val_accuracy: 0.1046 - val_loss: 2.3065
# Epoch 3/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.1339 - loss: 2.2870 - val_accuracy: 0.1017 - val_loss: 2.3152
# Epoch 4/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.1427 - loss: 2.2743 - val_accuracy: 0.1045 - val_loss: 2.3229
# Epoch 5/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.1536 - loss: 2.2590 - val_accuracy: 0.1023 - val_loss: 2.3319
# Epoch 6/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.1717 - loss: 2.2383 - val_accuracy: 0.1037 - val_loss: 2.3436
# Epoch 7/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.1872 - loss: 2.2096 - val_accuracy: 0.1018 - val_loss: 2.3601
# Epoch 8/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.2013 - loss: 2.1885 - val_accuracy: 0.1037 - val_loss: 2.3830
# Epoch 9/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.2179 - loss: 2.1574 - val_accuracy: 0.1037 - val_loss: 2.3957
# Epoch 10/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.2325 - loss: 2.1242 - val_accuracy: 0.1038 - val_loss: 2.4195
# Epoch 11/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.2559 - loss: 2.0866 - val_accuracy: 0.1017 - val_loss: 2.4475
# Epoch 12/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.2660 - loss: 2.0518 - val_accuracy: 0.1012 - val_loss: 2.4617
# Epoch 13/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.2892 - loss: 2.0114 - val_accuracy: 0.1009 - val_loss: 2.4813
# Epoch 14/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3060 - loss: 1.9692 - val_accuracy: 0.1020 - val_loss: 2.5128
# Epoch 15/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.3245 - loss: 1.9332 - val_accuracy: 0.0998 - val_loss: 2.5494
# Epoch 16/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.3401 - loss: 1.8886 - val_accuracy: 0.1016 - val_loss: 2.5944
# Epoch 17/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.3540 - loss: 1.8518 - val_accuracy: 0.0992 - val_loss: 2.6357
# Epoch 18/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.3721 - loss: 1.8100 - val_accuracy: 0.1003 - val_loss: 2.6547
# Epoch 19/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.3896 - loss: 1.7732 - val_accuracy: 0.1034 - val_loss: 2.7022
# Epoch 20/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4046 - loss: 1.7342 - val_accuracy: 0.1051 - val_loss: 2.7247
# Epoch 21/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4204 - loss: 1.6908 - val_accuracy: 0.1016 - val_loss: 2.7637
# Epoch 22/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.4288 - loss: 1.6643 - val_accuracy: 0.1011 - val_loss: 2.8155
# Epoch 23/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.4492 - loss: 1.6207 - val_accuracy: 0.1028 - val_loss: 2.8356
# Epoch 24/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4570 - loss: 1.5873 - val_accuracy: 0.1053 - val_loss: 2.8890
# Epoch 25/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.4821 - loss: 1.5382 - val_accuracy: 0.1045 - val_loss: 2.9626
# Epoch 26/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.4919 - loss: 1.5093 - val_accuracy: 0.1041 - val_loss: 2.9870
# Epoch 27/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.4978 - loss: 1.4834 - val_accuracy: 0.1021 - val_loss: 3.0505
# Epoch 28/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.5138 - loss: 1.4375 - val_accuracy: 0.1042 - val_loss: 3.1022
# Epoch 29/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.5267 - loss: 1.4123 - val_accuracy: 0.1036 - val_loss: 3.1366
# Epoch 30/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.5358 - loss: 1.3827 - val_accuracy: 0.1041 - val_loss: 3.1896
# Epoch 31/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.5468 - loss: 1.3487 - val_accuracy: 0.1068 - val_loss: 3.2550
# Epoch 32/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5558 - loss: 1.3262 - val_accuracy: 0.1094 - val_loss: 3.2934
# Epoch 33/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5727 - loss: 1.2878 - val_accuracy: 0.1059 - val_loss: 3.3682
# Epoch 34/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.5826 - loss: 1.2566 - val_accuracy: 0.1091 - val_loss: 3.3944
# Epoch 35/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.5910 - loss: 1.2284 - val_accuracy: 0.1042 - val_loss: 3.4558
# Epoch 36/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5950 - loss: 1.2126 - val_accuracy: 0.1063 - val_loss: 3.4923
# Epoch 37/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6050 - loss: 1.1853 - val_accuracy: 0.1072 - val_loss: 3.5672
# Epoch 38/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.6125 - loss: 1.1584 - val_accuracy: 0.1020 - val_loss: 3.6046
# Epoch 39/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6305 - loss: 1.1251 - val_accuracy: 0.1008 - val_loss: 3.6660
# Epoch 40/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6326 - loss: 1.1091 - val_accuracy: 0.1072 - val_loss: 3.7251
# Epoch 41/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.6415 - loss: 1.0852 - val_accuracy: 0.1037 - val_loss: 3.8110
# Epoch 42/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6524 - loss: 1.0584 - val_accuracy: 0.1061 - val_loss: 3.8523
# Epoch 43/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6631 - loss: 1.0273 - val_accuracy: 0.1060 - val_loss: 3.9161
# Epoch 44/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.6692 - loss: 1.0091 - val_accuracy: 0.1077 - val_loss: 3.9565
# Epoch 45/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6761 - loss: 0.9895 - val_accuracy: 0.0997 - val_loss: 4.0531
# Epoch 46/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6843 - loss: 0.9688 - val_accuracy: 0.1049 - val_loss: 4.0933
# Epoch 47/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.6924 - loss: 0.9436 - val_accuracy: 0.1060 - val_loss: 4.1532
# Epoch 48/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.6972 - loss: 0.9298 - val_accuracy: 0.1082 - val_loss: 4.2133
# Epoch 49/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.7045 - loss: 0.9122 - val_accuracy: 0.1067 - val_loss: 4.2555
# Epoch 50/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.7112 - loss: 0.8884 - val_accuracy: 0.1053 - val_loss: 4.3580
# Epoch 51/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.7179 - loss: 0.8761 - val_accuracy: 0.1070 - val_loss: 4.4094
# Epoch 52/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.7243 - loss: 0.8549 - val_accuracy: 0.1031 - val_loss: 4.4553
# Epoch 53/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.7289 - loss: 0.8359 - val_accuracy: 0.1037 - val_loss: 4.5480
# Epoch 54/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.7368 - loss: 0.8161 - val_accuracy: 0.1034 - val_loss: 4.6022
# Epoch 55/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.7424 - loss: 0.7989 - val_accuracy: 0.1023 - val_loss: 4.6931
# Epoch 56/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7458 - loss: 0.7854 - val_accuracy: 0.1045 - val_loss: 4.7350
# Epoch 57/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7508 - loss: 0.7726 - val_accuracy: 0.1048 - val_loss: 4.8064
# Epoch 58/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.7625 - loss: 0.7451 - val_accuracy: 0.1075 - val_loss: 4.8668
# Epoch 59/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7637 - loss: 0.7367 - val_accuracy: 0.1040 - val_loss: 4.9628
# Epoch 60/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7713 - loss: 0.7170 - val_accuracy: 0.1060 - val_loss: 5.0135
# Epoch 61/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.7718 - loss: 0.7136 - val_accuracy: 0.1046 - val_loss: 5.0610
# Epoch 62/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7824 - loss: 0.6867 - val_accuracy: 0.1023 - val_loss: 5.1428
# Epoch 63/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7816 - loss: 0.6827 - val_accuracy: 0.1036 - val_loss: 5.2191
# Epoch 64/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.7893 - loss: 0.6622 - val_accuracy: 0.1018 - val_loss: 5.2344
# Epoch 65/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7939 - loss: 0.6483 - val_accuracy: 0.1058 - val_loss: 5.3742
# Epoch 66/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7962 - loss: 0.6363 - val_accuracy: 0.1060 - val_loss: 5.3996
# Epoch 67/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8013 - loss: 0.6257 - val_accuracy: 0.1032 - val_loss: 5.4868
# Epoch 68/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8078 - loss: 0.6101 - val_accuracy: 0.1029 - val_loss: 5.5180
# Epoch 69/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8120 - loss: 0.6015 - val_accuracy: 0.1029 - val_loss: 5.6241
# Epoch 70/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8131 - loss: 0.5938 - val_accuracy: 0.1047 - val_loss: 5.7174
# Epoch 71/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8212 - loss: 0.5704 - val_accuracy: 0.1035 - val_loss: 5.7655
# Epoch 72/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8246 - loss: 0.5598 - val_accuracy: 0.1040 - val_loss: 5.8977
# Epoch 73/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8257 - loss: 0.5505 - val_accuracy: 0.1046 - val_loss: 5.9091
# Epoch 74/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.8322 - loss: 0.5390 - val_accuracy: 0.1085 - val_loss: 5.9795
# Epoch 75/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8346 - loss: 0.5309 - val_accuracy: 0.1035 - val_loss: 6.0884
# Epoch 76/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.8416 - loss: 0.5162 - val_accuracy: 0.1064 - val_loss: 6.1205
# Epoch 77/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8424 - loss: 0.5103 - val_accuracy: 0.1066 - val_loss: 6.2008
# Epoch 78/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8446 - loss: 0.4978 - val_accuracy: 0.1032 - val_loss: 6.3027
# Epoch 79/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8442 - loss: 0.4932 - val_accuracy: 0.1082 - val_loss: 6.3422
# Epoch 80/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8522 - loss: 0.4774 - val_accuracy: 0.1069 - val_loss: 6.4464
# Epoch 81/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8548 - loss: 0.4696 - val_accuracy: 0.1035 - val_loss: 6.4915
# Epoch 82/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8569 - loss: 0.4647 - val_accuracy: 0.1029 - val_loss: 6.5874
# Epoch 83/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8615 - loss: 0.4549 - val_accuracy: 0.1063 - val_loss: 6.6553
# Epoch 84/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.8634 - loss: 0.4484 - val_accuracy: 0.1017 - val_loss: 6.7656
# Epoch 85/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8671 - loss: 0.4343 - val_accuracy: 0.1033 - val_loss: 6.8018
# Epoch 86/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8683 - loss: 0.4264 - val_accuracy: 0.1060 - val_loss: 6.8625
# Epoch 87/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8665 - loss: 0.4282 - val_accuracy: 0.1047 - val_loss: 6.9614
# Epoch 88/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8723 - loss: 0.4140 - val_accuracy: 0.1072 - val_loss: 7.0311
# Epoch 89/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8752 - loss: 0.4078 - val_accuracy: 0.1048 - val_loss: 7.1233
# Epoch 90/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8805 - loss: 0.3966 - val_accuracy: 0.1038 - val_loss: 7.1926
# Epoch 91/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8820 - loss: 0.3851 - val_accuracy: 0.1011 - val_loss: 7.2463
# Epoch 92/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8851 - loss: 0.3779 - val_accuracy: 0.1027 - val_loss: 7.2684
# Epoch 93/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8861 - loss: 0.3730 - val_accuracy: 0.1036 - val_loss: 7.3501
# Epoch 94/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.8914 - loss: 0.3611 - val_accuracy: 0.1044 - val_loss: 7.5332
# Epoch 95/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8895 - loss: 0.3654 - val_accuracy: 0.1029 - val_loss: 7.5599
# Epoch 96/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8903 - loss: 0.3618 - val_accuracy: 0.1052 - val_loss: 7.6269
# Epoch 97/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8954 - loss: 0.3451 - val_accuracy: 0.1021 - val_loss: 7.6870
# Epoch 98/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8953 - loss: 0.3422 - val_accuracy: 0.1058 - val_loss: 7.8055
# Epoch 99/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.8984 - loss: 0.3338 - val_accuracy: 0.1026 - val_loss: 7.8600
# Epoch 100/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9017 - loss: 0.3262 - val_accuracy: 0.1049 - val_loss: 7.9213

# %%
history_random = model.history.history  # 무작위 레이블 학습 결과 가져오기

# 에포크 범위 설정
epochs = range(1, len(history_random['loss']) + 1)

# 학습 손실 그래프
plt.figure()
plt.plot(epochs, history_random['loss'], 'r-', label='Training Loss')
plt.plot(epochs, history_random['val_loss'], 'r--', label='Validation Loss')
plt.title('Training and Validation Loss with Random Labels')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 학습 정확도 그래프
plt.figure()
plt.plot(epochs, history_random['accuracy'], 'b-', label='Training Accuracy')
plt.plot(epochs, history_random['val_accuracy'], 'b--', label='Validation Accuracy')
plt.title('Training and Validation Accuracy with Random Labels')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# 5-5
num_validation_samples = 10000
np.random.shuffle(data)
validation_data = data[:num_validation_samples]
training_data = data[num_validation_samples:]
model = get_model()
model.fit(training_data, ...)
validation_score = model.evaluate(validation_data, ...)
...
model = get_model()
model.fit(np.concatenate([training_data,
          validation_data]), ...)
test_score = model.evaluate(test_data, ...)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-7cc7924fac9b> in <cell line: 3>()
#       1 # 5-5
#       2 num_validation_samples = 10000
# ----> 3 np.random.shuffle(data)
#       4 validation_data = data[:num_validation_samples]
#       5 training_data = data[num_validation_samples:]
#
# NameError: name 'data' is not defined

# %%
model = keras.Sequential([layers.Dense(10, activation="softmax")])
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accurac"])
history_small_model = model.fit(
    trian_images, train_labels,
    epochs=20,
    batch_size=128,
    validation_split=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-5d031914f3ea> in <cell line: 5>()
#       4               metrics=["accurac"])
#       5 history_small_model = model.fit(
# ----> 6     trian_images, train_labels,
#       7     epochs=20,
#       8     batch_size=128,
#
# NameError: name 'trian_images' is not defined
